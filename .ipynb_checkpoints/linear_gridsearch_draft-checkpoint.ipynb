# %%
import os
import pandas as pd
import numpy as np
import csv

from itertools import cycle, product
import argparse
import warnings

from sklearn.preprocessing import normalize
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, RepeatedStratifiedKFold, train_test_split
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.decomposition import NMF
from sklearn.exceptions import ConvergenceWarning

import matplotlib.pyplot as plt
plt.switch_backend('Agg') # this suppresses the console for plotting  
import seaborn as sns

# import private scripts
import load_kmer_cnts_jf
import stats_utils_AEB

# %%
# directories (make sure date exists)
date = 'testing_120418/'
output_dir = os.environ['HOME'] + '/deep_learning_microbiome/analysis/kmers/linear/' + str(date)


# filter out warnings about convergence 
warnings.filterwarnings("ignore", category=ConvergenceWarning)


kmer_size = None
cv_gridsearch = None # number of folds for grid search
cv_testfolds = None # number of folds for actual training of the best model
n_iter = None # number of iterations of cross-validation
random_state = None

# %%
# Lists of data sets to be tested
# Each item consists of two lists: from the first, the healthy samples will be extracted.
# From the second, diseased samples will be extracted.
# The two sets will then be combined. 
data_sets_to_use = [
    [['MetaHIT'], ['MetaHIT']],
    #[['Qin_et_al'], ['Qin_et_al']],
    #[['Zeller_2014'], ['Zeller_2014']],
    #[['LiverCirrhosis'], ['LiverCirrhosis']],
    #[['Karlsson_2013_no_adapter'], ['Karlsson_2013_no_adapter']],
    #[['RA_no_adapter'], ['RA_no_adapter']],
    #[['LeChatelier'], ['LeChatelier']],
    #[['Feng'], ['Feng']]
   ]

# %%
# Dictionary of parameters for each model 
param_dict = {       
    "rf": {"n_estimators": [400],
           "criterion": ["gini"],
           "max_features": ["sqrt"],
           "max_depth": [None],
           "min_samples_split": [2],
           "n_jobs": [1]},
    "lassoLR": {"penalty": ["l1"], 
                "solver": ["saga", "liblinear"]}
    }

# %% [markdown]
# # From figuring out target distribution

# %%
# just to help run it in jupyter #
kmer_size = 5
n_factor = 5
###

for data_set in data_sets_to_use:
    data_set = data_set[0]
        
    # Retrieve diseased data and labels
    allowed_labels = ['0', '1']
    kmer_cnts, accessions, labelz, domain_labels = load_kmer_cnts_jf.load_kmers(kmer_size, data_set, allowed_labels)
    print("LOADED DATASET " + str(data_set[0]) + ": " + str(len(kmer_cnts)) + " SAMPLES")
    labelz=np.asarray(labelz).astype(np.int)
    
    for n in [0]:
        if n == 0:
            data_normalized = normalize(kmer_cnts, axis = 1, norm = 'l1')
            data_normalized, labels = shuffle(data_normalized, labelz, random_state=0) 
            x = data_normalized
            y = labels
                    
        else:
            data_normalized = normalize(kmer_cnts, axis = 1, norm = 'l1')
            data_normalized = stats_utils_AEB.NMF_factor(data_normalized, kmer_size, n_components = int(n), 
                                                     title=(str(data_set) + str(kmer_size) + "mers" 
                                                            + str(n) + "factors"))
            data_normalized, labels = shuffle(data_normalized, labelz, random_state=0)
            x = data_normalized
            y = labels

# %%
kmer_cnts

# %%
targets, counts = np.unique(y, return_counts=True)

print(targets)
print(counts)
print(counts[1]/(counts[1] + counts[0]))

# %% [markdown]
# # RF

# %%
# just to help run it in jupyter #
learn_type = 'rf'
cv_gridsearch = 10
n_iter_grid = 1
#n_splits = 5
#n_repeats = 1

###

param_grid = param_dict[learn_type]

scoring = {
    'Acc': 'accuracy',
    'AUC': 'roc_auc',
    'F1': 'f1', # weighted average of precision and recall
    'Precision': 'precision',
    'Recall': 'recall'
}

estimator = RandomForestClassifier(n_estimators=500, max_depth=None, min_samples_split=2, n_jobs=1)
k_fold = RepeatedStratifiedKFold(n_splits=cv_gridsearch, n_repeats=n_iter_grid)
grid_search = GridSearchCV(estimator, param_grid, cv = k_fold, n_jobs = 1, scoring=scoring, refit = False)
grid_search = grid_search.fit(x, y)            
grid_search_results = grid_search.cv_results_

# %%
#grid_search_results

# %%
trees = np.array(grid_search_results['param_n_estimators'])

# %%
rank_auc = np.array(grid_search_results['rank_test_AUC'])
rank_acc = np.array(grid_search_results['rank_test_Acc'])
rank_f1 = np.array(grid_search_results['rank_test_F1'])

# %%
aucs = np.array(grid_search_results['mean_test_AUC'])
accuracies = np.array(grid_search_results['mean_test_Acc'])
f1s = np.array(grid_search_results['mean_test_F1'])
precisions = np.array(grid_search_results['mean_test_Precision'])
recalls = np.array(grid_search_results['mean_test_Recall'])

# %%
all_params = np.array(grid_search_results['params'])

# %%
with open(graph_dir + '101418_can_delete/summ_table.csv', 'w', newline='') as csvfile:
    fieldnames = ['dataset', 'kmer_size', 'n_splits', 'n_repeats', 'acc', 'auc', 'precision', 'recall', 'f1',
                      'model', 'NMF_factors', 'params']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for i in range(len(aucs)):
        param_grid = all_params[i]
        criterion = param_grid["criterion"]
        max_depth = param_grid["max_depth"]
        max_features = param_grid["max_features"]
        min_samples_split = param_grid["min_samples_split"]
        n_estimators = param_grid["n_estimators"]
        n_jobs = 1
        current_estimator = RandomForestClassifier(criterion=criterion, max_depth=max_depth, 
                                                max_features=max_features, min_samples_split=min_samples_split,
                                                n_estimators=n_estimators,n_jobs=n_jobs)
    
    #results saved to csv

        writer.writerow({
                'dataset': str(data_set),
                'kmer_size': kmer_size,
                'n_splits': cv_gridsearch,
                'n_repeats': n_iter_grid,
                'acc': accuracies[i],
                'auc': aucs[i],
                'precision': precisions[i],
                'recall': recalls[i],
                'f1': f1s[i],
                'model': learn_type,
                'NMF_factors': n_factor,
                'params': str(all_params[i])
            })
'''   
print(
        ">auroc:" + str(aucs[i]) + 
        " acc:" + (str(accuracies[i]) + 
        " f1:" + (str(f1s[i]) +
        " recall:" + str(recalls[i]) +
        " precision:" + str(precisions[i]) +
        " dataset:" + str(data_set) +
        " model:" + learn_type +  
        " NMFfactors: "+ str(n_factor) + 
        " kmer_size:" + str(kmer_size) + 
        #" no_trees:" + str(trees[i]))) +
        " params:" + str(all_params[i])
    )))
    '''

# %%
df_known_summ = pd.read_csv(graph_dir + '101418_can_delete/summ_table.csv')
df_known_summ

# %% [markdown]
# # Trying shap

# %%
# load JS visualization code to notebook
shap.initjs()

# %%
clf = RandomForestClassifier()
clf = clf.fit(x,y)

# %%
explainer = shap.TreeExplainer(clf)
shap_values = explainer.shap_values(x)

# %%
shap.summary_plot(shap_values, x)

# %% [markdown]
# # LassoLR

# %%
# just to help run it in jupyter #
learn_type = 'lassoLR'
cv_gridsearch = 10
n_iter_grid = 20
###

param_grid = param_dict[learn_type]

scoring = {
    'Acc': 'accuracy',
    'AUC': 'roc_auc'
}

# %%
kmer_size = 5
n_factor = 5

for data_set in data_sets_to_use:
    data_set = data_set[0]
        
    # Retrieve diseased data and labels
    allowed_labels = ['0', '1']
    kmer_cnts, accessions, labelz, domain_labels = load_kmer_cnts_jf.load_kmers(kmer_size, data_set, allowed_labels)
    print("LOADED DATASET " + str(data_set[0]) + ": " + str(len(kmer_cnts)) + " SAMPLES")
    labelz=np.asarray(labelz).astype(np.int)
# Out:
# MetaHIT
# LOADED DATASET MetaHIT: 110 SAMPLES

# %%
for n in [0, 5]:
    if n == 0:
        data_normalized = normalize(kmer_cnts, axis = 1, norm = 'l1')
        data_normalized, labels = shuffle(data_normalized, labelz, random_state=0) 
        x = data_normalized
        y = labels
                    
    else:
        data_normalized = normalize(kmer_cnts, axis = 1, norm = 'l1')
        data_normalized = stats_utils_AEB.NMF_factor(data_normalized, kmer_size, n_components = int(n), 
                                                     title=(str(data_set) + str(kmer_size) + "mers" 
                                                            + str(n) + "factors"))
        data_normalized, labels = shuffle(data_normalized, labelz, random_state=0)
        x = data_normalized
        y = labels

# %%
param_grid = param_dict[learn_type]

# %%
param_grid
# Out:
# {'penalty': ['l1'], 'solver': ['saga', 'liblinear']}

# %%
scoring = {
    'Acc': 'accuracy',
    'AUC': 'roc_auc',
                    }

# %%
estimator = LogisticRegression(penalty = 'l1', solver = 'saga', n_jobs = 1)

# %%
k_fold = RepeatedStratifiedKFold(n_splits=cv_gridsearch, n_repeats=n_iter_grid)

# %%
grid_search = GridSearchCV(estimator, 
                           param_grid, 
                           cv = k_fold, 
                           n_jobs = 1,
                           scoring=scoring, 
                           refit = 'AUC')

# %%
grid_search.fit(x, y)
# Out:
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=<sklearn.model_selection._split.RepeatedStratifiedKFold object at 0x7f8b5816ce10>,
#        error_score='raise-deprecating',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn', n_jobs=1,
#           penalty='l1', random_state=None, solver='saga', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=1,
#        param_grid={'penalty': ['l1'], 'solver': ['saga', 'liblinear']},
#        pre_dispatch='2*n_jobs', refit='AUC', return_train_score='warn',
#        scoring={'Acc': 'accuracy', 'AUC': 'roc_auc'}, verbose=0)

# %%
grid_search_results = grid_search.cv_results_

# %%
grid_search_results
# Out:
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split5_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split6_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split7_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split8_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split9_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split10_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split11_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split12_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split13_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split14_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split15_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split16_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split17_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split18_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split19_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split20_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split21_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split22_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split23_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split24_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split25_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split26_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split27_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split28_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split29_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split30_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split31_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split32_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split33_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split34_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split35_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split36_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split37_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split38_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split39_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split40_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split41_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split42_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split43_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split44_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split45_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split46_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split47_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split48_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split49_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split50_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split51_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split52_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split53_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split54_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split55_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split56_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split57_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split58_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split59_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split60_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split61_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split62_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split63_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split64_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split65_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split66_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split67_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split68_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split69_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split70_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split71_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split72_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split73_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split74_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split75_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split76_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split77_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split78_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split79_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split80_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split81_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split82_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split83_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split84_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split85_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split86_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split87_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split88_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split89_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split90_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split91_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split92_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split93_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split94_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split95_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split96_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split97_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split98_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split99_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split100_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split101_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split102_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split103_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split104_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split105_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split106_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split107_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split108_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split109_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split110_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split111_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split112_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split113_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split114_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split115_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split116_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split117_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split118_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split119_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split120_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split121_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split122_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split123_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split124_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split125_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split126_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split127_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split128_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split129_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split130_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split131_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split132_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split133_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split134_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split135_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split136_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /pollard/home/abustion/miniconda3/envs/DL_1118/lib/python3.6/site-packages/sklearn/utils/deprecation.py:125: FutureWarning: You are accessing a training score ('split137_train_Acc'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# ...
#  'split15_test_AUC': array([0.5, 0.5]),
#  'split16_test_AUC': array([0.5, 0.5]),
#  'split17_test_AUC': array([0.5, 0.5]),
#  'split18_test_AUC': array([0.5, 0.5]),
#  'split19_test_AUC': array([0.5, 0.5]),
#  'split20_test_AUC': array([0.5, 0.5]),
#  'split21_test_AUC': array([0.5, 0.5]),
#  'split22_test_AUC': array([0.5, 0.5]),
#  'split23_test_AUC': array([0.5, 0.5]),
#  'split24_test_AUC': array([0.5, 0.5]),
#  'split25_test_AUC': array([0.5, 0.5]),
#  'split26_test_AUC': array([0.5, 0.5]),
#  'split27_test_AUC': array([0.5, 0.5]),
#  'split28_test_AUC': array([0.5, 0.5]),
#  'split29_test_AUC': array([0.5, 0.5]),
#  'split30_test_AUC': array([0.5, 0.5]),
#  'split31_test_AUC': array([0.5, 0.5]),
#  'split32_test_AUC': array([0.5, 0.5]),
#  'split33_test_AUC': array([0.5, 0.5]),
#  'split34_test_AUC': array([0.5, 0.5]),
#  'split35_test_AUC': array([0.5, 0.5]),
#  'split36_test_AUC': array([0.5, 0.5]),
#  'split37_test_AUC': array([0.5, 0.5]),
#  'split38_test_AUC': array([0.5, 0.5]),
#  'split39_test_AUC': array([0.5, 0.5]),
#  'split40_test_AUC': array([0.5, 0.5]),
#  'split41_test_AUC': array([0.5, 0.5]),
#  'split42_test_AUC': array([0.5, 0.5]),
#  'split43_test_AUC': array([0.5, 0.5]),
#  'split44_test_AUC': array([0.5, 0.5]),
#  'split45_test_AUC': array([0.5, 0.5]),
#  'split46_test_AUC': array([0.5, 0.5]),
#  'split47_test_AUC': array([0.5, 0.5]),
#  'split48_test_AUC': array([0.5, 0.5]),
#  'split49_test_AUC': array([0.5, 0.5]),
#  'split50_test_AUC': array([0.5, 0.5]),
#  'split51_test_AUC': array([0.5, 0.5]),
#  'split52_test_AUC': array([0.5, 0.5]),
#  'split53_test_AUC': array([0.5, 0.5]),
#  'split54_test_AUC': array([0.5, 0.5]),
#  'split55_test_AUC': array([0.5, 0.5]),
#  'split56_test_AUC': array([0.5, 0.5]),
#  'split57_test_AUC': array([0.5, 0.5]),
#  'split58_test_AUC': array([0.5, 0.5]),
#  'split59_test_AUC': array([0.5, 0.5]),
#  'split60_test_AUC': array([0.5, 0.5]),
#  'split61_test_AUC': array([0.5, 0.5]),
#  'split62_test_AUC': array([0.5, 0.5]),
#  'split63_test_AUC': array([0.5, 0.5]),
#  'split64_test_AUC': array([0.5, 0.5]),
#  'split65_test_AUC': array([0.5, 0.5]),
#  'split66_test_AUC': array([0.5, 0.5]),
#  'split67_test_AUC': array([0.5, 0.5]),
#  'split68_test_AUC': array([0.5, 0.5]),
#  'split69_test_AUC': array([0.5, 0.5]),
#  'split70_test_AUC': array([0.5, 0.5]),
#  'split71_test_AUC': array([0.5, 0.5]),
#  'split72_test_AUC': array([0.5, 0.5]),
#  'split73_test_AUC': array([0.5, 0.5]),
#  'split74_test_AUC': array([0.5, 0.5]),
#  'split75_test_AUC': array([0.5, 0.5]),
#  'split76_test_AUC': array([0.5, 0.5]),
#  'split77_test_AUC': array([0.5, 0.5]),
#  'split78_test_AUC': array([0.5, 0.5]),
#  'split79_test_AUC': array([0.5, 0.5]),
#  'split80_test_AUC': array([0.5, 0.5]),
#  'split81_test_AUC': array([0.5, 0.5]),
#  'split82_test_AUC': array([0.5, 0.5]),
#  'split83_test_AUC': array([0.5, 0.5]),
#  'split84_test_AUC': array([0.5, 0.5]),
#  'split85_test_AUC': array([0.5, 0.5]),
#  'split86_test_AUC': array([0.5, 0.5]),
#  'split87_test_AUC': array([0.5, 0.5]),
#  'split88_test_AUC': array([0.5, 0.5]),
#  'split89_test_AUC': array([0.5, 0.5]),
#  'split90_test_AUC': array([0.5, 0.5]),
#  'split91_test_AUC': array([0.5, 0.5]),
#  'split92_test_AUC': array([0.5, 0.5]),
#  'split93_test_AUC': array([0.5, 0.5]),
#  'split94_test_AUC': array([0.5, 0.5]),
#  'split95_test_AUC': array([0.5, 0.5]),
#  'split96_test_AUC': array([0.5, 0.5]),
#  'split97_test_AUC': array([0.5, 0.5]),
#  'split98_test_AUC': array([0.5, 0.5]),
#  'split99_test_AUC': array([0.5, 0.5]),
#  'split100_test_AUC': array([0.5, 0.5]),
#  'split101_test_AUC': array([0.5, 0.5]),
#  'split102_test_AUC': array([0.5, 0.5]),
#  'split103_test_AUC': array([0.5, 0.5]),
#  'split104_test_AUC': array([0.5, 0.5]),
#  'split105_test_AUC': array([0.5, 0.5]),
#  'split106_test_AUC': array([0.5, 0.5]),
#  'split107_test_AUC': array([0.5, 0.5]),
#  'split108_test_AUC': array([0.5, 0.5]),
#  'split109_test_AUC': array([0.5, 0.5]),
#  'split110_test_AUC': array([0.5, 0.5]),
#  'split111_test_AUC': array([0.5, 0.5]),
#  'split112_test_AUC': array([0.5, 0.5]),
#  'split113_test_AUC': array([0.5, 0.5]),
#  'split114_test_AUC': array([0.5, 0.5]),
#  'split115_test_AUC': array([0.5, 0.5]),
#  'split116_test_AUC': array([0.5, 0.5]),
#  'split117_test_AUC': array([0.5, 0.5]),
#  'split118_test_AUC': array([0.5, 0.5]),
#  'split119_test_AUC': array([0.5, 0.5]),
#  'split120_test_AUC': array([0.5, 0.5]),
#  'split121_test_AUC': array([0.5, 0.5]),
#  'split122_test_AUC': array([0.5, 0.5]),
#  'split123_test_AUC': array([0.5, 0.5]),
#  'split124_test_AUC': array([0.5, 0.5]),
#  'split125_test_AUC': array([0.5, 0.5]),
#  'split126_test_AUC': array([0.5, 0.5]),
#  'split127_test_AUC': array([0.5, 0.5]),
#  'split128_test_AUC': array([0.5, 0.5]),
#  'split129_test_AUC': array([0.5, 0.5]),
#  'split130_test_AUC': array([0.5, 0.5]),
#  'split131_test_AUC': array([0.5, 0.5]),
#  'split132_test_AUC': array([0.5, 0.5]),
#  'split133_test_AUC': array([0.5, 0.5]),
#  'split134_test_AUC': array([0.5, 0.5]),
#  'split135_test_AUC': array([0.5, 0.5]),
#  'split136_test_AUC': array([0.5, 0.5]),
#  'split137_test_AUC': array([0.5, 0.5]),
#  'split138_test_AUC': array([0.5, 0.5]),
#  'split139_test_AUC': array([0.5, 0.5]),
#  'split140_test_AUC': array([0.5, 0.5]),
#  'split141_test_AUC': array([0.5, 0.5]),
#  'split142_test_AUC': array([0.5, 0.5]),
#  'split143_test_AUC': array([0.5, 0.5]),
#  'split144_test_AUC': array([0.5, 0.5]),
#  'split145_test_AUC': array([0.5, 0.5]),
#  'split146_test_AUC': array([0.5, 0.5]),
#  'split147_test_AUC': array([0.5, 0.5]),
#  'split148_test_AUC': array([0.5, 0.5]),
#  'split149_test_AUC': array([0.5, 0.5]),
#  'split150_test_AUC': array([0.5, 0.5]),
#  'split151_test_AUC': array([0.5, 0.5]),
#  'split152_test_AUC': array([0.5, 0.5]),
#  'split153_test_AUC': array([0.5, 0.5]),
#  'split154_test_AUC': array([0.5, 0.5]),
#  'split155_test_AUC': array([0.5, 0.5]),
#  'split156_test_AUC': array([0.5, 0.5]),
#  'split157_test_AUC': array([0.5, 0.5]),
#  'split158_test_AUC': array([0.5, 0.5]),
#  'split159_test_AUC': array([0.5, 0.5]),
#  'split160_test_AUC': array([0.5, 0.5]),
#  'split161_test_AUC': array([0.5, 0.5]),
#  'split162_test_AUC': array([0.5, 0.5]),
#  'split163_test_AUC': array([0.5, 0.5]),
#  'split164_test_AUC': array([0.5, 0.5]),
#  'split165_test_AUC': array([0.5, 0.5]),
#  'split166_test_AUC': array([0.5, 0.5]),
#  'split167_test_AUC': array([0.5, 0.5]),
#  'split168_test_AUC': array([0.5, 0.5]),
#  'split169_test_AUC': array([0.5, 0.5]),
#  'split170_test_AUC': array([0.5, 0.5]),
#  'split171_test_AUC': array([0.5, 0.5]),
#  'split172_test_AUC': array([0.5, 0.5]),
#  'split173_test_AUC': array([0.5, 0.5]),
#  'split174_test_AUC': array([0.5, 0.5]),
#  'split175_test_AUC': array([0.5, 0.5]),
#  'split176_test_AUC': array([0.5, 0.5]),
#  'split177_test_AUC': array([0.5, 0.5]),
#  'split178_test_AUC': array([0.5, 0.5]),
#  'split179_test_AUC': array([0.5, 0.5]),
#  'split180_test_AUC': array([0.5, 0.5]),
#  'split181_test_AUC': array([0.5, 0.5]),
#  'split182_test_AUC': array([0.5, 0.5]),
#  'split183_test_AUC': array([0.5, 0.5]),
#  'split184_test_AUC': array([0.5, 0.5]),
#  'split185_test_AUC': array([0.5, 0.5]),
#  'split186_test_AUC': array([0.5, 0.5]),
#  'split187_test_AUC': array([0.5, 0.5]),
#  'split188_test_AUC': array([0.5, 0.5]),
#  'split189_test_AUC': array([0.5, 0.5]),
#  'split190_test_AUC': array([0.5, 0.5]),
#  'split191_test_AUC': array([0.5, 0.5]),
#  'split192_test_AUC': array([0.5, 0.5]),
#  'split193_test_AUC': array([0.5, 0.5]),
#  'split194_test_AUC': array([0.5, 0.5]),
#  'split195_test_AUC': array([0.5, 0.5]),
#  'split196_test_AUC': array([0.5, 0.5]),
#  'split197_test_AUC': array([0.5, 0.5]),
#  'split198_test_AUC': array([0.5, 0.5]),
#  'split199_test_AUC': array([0.5, 0.5]),
#  'mean_test_AUC': array([0.5, 0.5]),
#  'std_test_AUC': array([0., 0.]),
#  'rank_test_AUC': array([1, 1], dtype=int32),
#  'split0_train_AUC': array([0.5, 0.5]),
#  'split1_train_AUC': array([0.5, 0.5]),
#  'split2_train_AUC': array([0.5, 0.5]),
#  'split3_train_AUC': array([0.5, 0.5]),
#  'split4_train_AUC': array([0.5, 0.5]),
#  'split5_train_AUC': array([0.5, 0.5]),
#  'split6_train_AUC': array([0.5, 0.5]),
#  'split7_train_AUC': array([0.5, 0.5]),
#  'split8_train_AUC': array([0.5, 0.5]),
#  'split9_train_AUC': array([0.5, 0.5]),
#  'split10_train_AUC': array([0.5, 0.5]),
#  'split11_train_AUC': array([0.5, 0.5]),
#  'split12_train_AUC': array([0.5, 0.5]),
#  'split13_train_AUC': array([0.5, 0.5]),
#  'split14_train_AUC': array([0.5, 0.5]),
#  'split15_train_AUC': array([0.5, 0.5]),
#  'split16_train_AUC': array([0.5, 0.5]),
#  'split17_train_AUC': array([0.5, 0.5]),
#  'split18_train_AUC': array([0.5, 0.5]),
#  'split19_train_AUC': array([0.5, 0.5]),
#  'split20_train_AUC': array([0.5, 0.5]),
#  'split21_train_AUC': array([0.5, 0.5]),
#  'split22_train_AUC': array([0.5, 0.5]),
#  'split23_train_AUC': array([0.5, 0.5]),
#  'split24_train_AUC': array([0.5, 0.5]),
#  'split25_train_AUC': array([0.5, 0.5]),
#  'split26_train_AUC': array([0.5, 0.5]),
#  'split27_train_AUC': array([0.5, 0.5]),
#  'split28_train_AUC': array([0.5, 0.5]),
#  'split29_train_AUC': array([0.5, 0.5]),
#  'split30_train_AUC': array([0.5, 0.5]),
#  'split31_train_AUC': array([0.5, 0.5]),
#  'split32_train_AUC': array([0.5, 0.5]),
#  'split33_train_AUC': array([0.5, 0.5]),
#  'split34_train_AUC': array([0.5, 0.5]),
#  'split35_train_AUC': array([0.5, 0.5]),
#  'split36_train_AUC': array([0.5, 0.5]),
#  'split37_train_AUC': array([0.5, 0.5]),
#  'split38_train_AUC': array([0.5, 0.5]),
#  'split39_train_AUC': array([0.5, 0.5]),
#  'split40_train_AUC': array([0.5, 0.5]),
#  'split41_train_AUC': array([0.5, 0.5]),
#  'split42_train_AUC': array([0.5, 0.5]),
#  'split43_train_AUC': array([0.5, 0.5]),
#  'split44_train_AUC': array([0.5, 0.5]),
#  'split45_train_AUC': array([0.5, 0.5]),
#  'split46_train_AUC': array([0.5, 0.5]),
#  'split47_train_AUC': array([0.5, 0.5]),
#  'split48_train_AUC': array([0.5, 0.5]),
#  'split49_train_AUC': array([0.5, 0.5]),
#  'split50_train_AUC': array([0.5, 0.5]),
#  'split51_train_AUC': array([0.5, 0.5]),
#  'split52_train_AUC': array([0.5, 0.5]),
#  'split53_train_AUC': array([0.5, 0.5]),
#  'split54_train_AUC': array([0.5, 0.5]),
#  'split55_train_AUC': array([0.5, 0.5]),
#  'split56_train_AUC': array([0.5, 0.5]),
#  'split57_train_AUC': array([0.5, 0.5]),
#  'split58_train_AUC': array([0.5, 0.5]),
#  'split59_train_AUC': array([0.5, 0.5]),
#  'split60_train_AUC': array([0.5, 0.5]),
#  'split61_train_AUC': array([0.5, 0.5]),
#  'split62_train_AUC': array([0.5, 0.5]),
#  'split63_train_AUC': array([0.5, 0.5]),
#  'split64_train_AUC': array([0.5, 0.5]),
#  'split65_train_AUC': array([0.5, 0.5]),
#  'split66_train_AUC': array([0.5, 0.5]),
#  'split67_train_AUC': array([0.5, 0.5]),
#  'split68_train_AUC': array([0.5, 0.5]),
#  'split69_train_AUC': array([0.5, 0.5]),
#  'split70_train_AUC': array([0.5, 0.5]),
#  'split71_train_AUC': array([0.5, 0.5]),
#  'split72_train_AUC': array([0.5, 0.5]),
#  'split73_train_AUC': array([0.5, 0.5]),
#  'split74_train_AUC': array([0.5, 0.5]),
#  'split75_train_AUC': array([0.5, 0.5]),
#  'split76_train_AUC': array([0.5, 0.5]),
#  'split77_train_AUC': array([0.5, 0.5]),
#  'split78_train_AUC': array([0.5, 0.5]),
#  'split79_train_AUC': array([0.5, 0.5]),
#  'split80_train_AUC': array([0.5, 0.5]),
#  'split81_train_AUC': array([0.5, 0.5]),
#  'split82_train_AUC': array([0.5, 0.5]),
#  'split83_train_AUC': array([0.5, 0.5]),
#  'split84_train_AUC': array([0.5, 0.5]),
#  'split85_train_AUC': array([0.5, 0.5]),
#  'split86_train_AUC': array([0.5, 0.5]),
#  'split87_train_AUC': array([0.5, 0.5]),
#  'split88_train_AUC': array([0.5, 0.5]),
#  'split89_train_AUC': array([0.5, 0.5]),
#  'split90_train_AUC': array([0.5, 0.5]),
#  'split91_train_AUC': array([0.5, 0.5]),
#  'split92_train_AUC': array([0.5, 0.5]),
#  'split93_train_AUC': array([0.5, 0.5]),
#  'split94_train_AUC': array([0.5, 0.5]),
#  'split95_train_AUC': array([0.5, 0.5]),
#  'split96_train_AUC': array([0.5, 0.5]),
#  'split97_train_AUC': array([0.5, 0.5]),
#  'split98_train_AUC': array([0.5, 0.5]),
#  'split99_train_AUC': array([0.5, 0.5]),
#  'split100_train_AUC': array([0.5, 0.5]),
#  'split101_train_AUC': array([0.5, 0.5]),
#  'split102_train_AUC': array([0.5, 0.5]),
#  'split103_train_AUC': array([0.5, 0.5]),
#  'split104_train_AUC': array([0.5, 0.5]),
#  'split105_train_AUC': array([0.5, 0.5]),
#  'split106_train_AUC': array([0.5, 0.5]),
#  'split107_train_AUC': array([0.5, 0.5]),
#  'split108_train_AUC': array([0.5, 0.5]),
#  'split109_train_AUC': array([0.5, 0.5]),
#  'split110_train_AUC': array([0.5, 0.5]),
#  'split111_train_AUC': array([0.5, 0.5]),
#  'split112_train_AUC': array([0.5, 0.5]),
#  'split113_train_AUC': array([0.5, 0.5]),
#  'split114_train_AUC': array([0.5, 0.5]),
#  'split115_train_AUC': array([0.5, 0.5]),
#  'split116_train_AUC': array([0.5, 0.5]),
#  'split117_train_AUC': array([0.5, 0.5]),
#  'split118_train_AUC': array([0.5, 0.5]),
#  'split119_train_AUC': array([0.5, 0.5]),
#  'split120_train_AUC': array([0.5, 0.5]),
#  'split121_train_AUC': array([0.5, 0.5]),
#  'split122_train_AUC': array([0.5, 0.5]),
#  'split123_train_AUC': array([0.5, 0.5]),
#  'split124_train_AUC': array([0.5, 0.5]),
#  'split125_train_AUC': array([0.5, 0.5]),
#  'split126_train_AUC': array([0.5, 0.5]),
#  'split127_train_AUC': array([0.5, 0.5]),
#  'split128_train_AUC': array([0.5, 0.5]),
#  'split129_train_AUC': array([0.5, 0.5]),
#  'split130_train_AUC': array([0.5, 0.5]),
#  'split131_train_AUC': array([0.5, 0.5]),
#  'split132_train_AUC': array([0.5, 0.5]),
#  'split133_train_AUC': array([0.5, 0.5]),
#  'split134_train_AUC': array([0.5, 0.5]),
#  'split135_train_AUC': array([0.5, 0.5]),
#  'split136_train_AUC': array([0.5, 0.5]),
#  'split137_train_AUC': array([0.5, 0.5]),
#  'split138_train_AUC': array([0.5, 0.5]),
#  'split139_train_AUC': array([0.5, 0.5]),
#  'split140_train_AUC': array([0.5, 0.5]),
#  'split141_train_AUC': array([0.5, 0.5]),
#  'split142_train_AUC': array([0.5, 0.5]),
#  'split143_train_AUC': array([0.5, 0.5]),
#  'split144_train_AUC': array([0.5, 0.5]),
#  'split145_train_AUC': array([0.5, 0.5]),
#  'split146_train_AUC': array([0.5, 0.5]),
#  'split147_train_AUC': array([0.5, 0.5]),
#  'split148_train_AUC': array([0.5, 0.5]),
#  'split149_train_AUC': array([0.5, 0.5]),
#  'split150_train_AUC': array([0.5, 0.5]),
#  'split151_train_AUC': array([0.5, 0.5]),
#  'split152_train_AUC': array([0.5, 0.5]),
#  'split153_train_AUC': array([0.5, 0.5]),
#  'split154_train_AUC': array([0.5, 0.5]),
#  'split155_train_AUC': array([0.5, 0.5]),
#  'split156_train_AUC': array([0.5, 0.5]),
#  'split157_train_AUC': array([0.5, 0.5]),
#  'split158_train_AUC': array([0.5, 0.5]),
#  'split159_train_AUC': array([0.5, 0.5]),
#  'split160_train_AUC': array([0.5, 0.5]),
#  'split161_train_AUC': array([0.5, 0.5]),
#  'split162_train_AUC': array([0.5, 0.5]),
#  'split163_train_AUC': array([0.5, 0.5]),
#  'split164_train_AUC': array([0.5, 0.5]),
#  'split165_train_AUC': array([0.5, 0.5]),
#  'split166_train_AUC': array([0.5, 0.5]),
#  'split167_train_AUC': array([0.5, 0.5]),
#  'split168_train_AUC': array([0.5, 0.5]),
#  'split169_train_AUC': array([0.5, 0.5]),
#  'split170_train_AUC': array([0.5, 0.5]),
#  'split171_train_AUC': array([0.5, 0.5]),
#  'split172_train_AUC': array([0.5, 0.5]),
#  'split173_train_AUC': array([0.5, 0.5]),
#  'split174_train_AUC': array([0.5, 0.5]),
#  'split175_train_AUC': array([0.5, 0.5]),
#  'split176_train_AUC': array([0.5, 0.5]),
#  'split177_train_AUC': array([0.5, 0.5]),
#  'split178_train_AUC': array([0.5, 0.5]),
#  'split179_train_AUC': array([0.5, 0.5]),
#  'split180_train_AUC': array([0.5, 0.5]),
#  'split181_train_AUC': array([0.5, 0.5]),
#  'split182_train_AUC': array([0.5, 0.5]),
#  'split183_train_AUC': array([0.5, 0.5]),
#  'split184_train_AUC': array([0.5, 0.5]),
#  'split185_train_AUC': array([0.5, 0.5]),
#  'split186_train_AUC': array([0.5, 0.5]),
#  'split187_train_AUC': array([0.5, 0.5]),
#  'split188_train_AUC': array([0.5, 0.5]),
#  'split189_train_AUC': array([0.5, 0.5]),
#  'split190_train_AUC': array([0.5, 0.5]),
#  'split191_train_AUC': array([0.5, 0.5]),
#  'split192_train_AUC': array([0.5, 0.5]),
#  'split193_train_AUC': array([0.5, 0.5]),
#  'split194_train_AUC': array([0.5, 0.5]),
#  'split195_train_AUC': array([0.5, 0.5]),
#  'split196_train_AUC': array([0.5, 0.5]),
#  'split197_train_AUC': array([0.5, 0.5]),
#  'split198_train_AUC': array([0.5, 0.5]),
#  'split199_train_AUC': array([0.5, 0.5]),
#  'mean_train_AUC': array([0.5, 0.5]),
#  'std_train_AUC': array([0., 0.])}

# %%
#scores
aucs = np.array(grid_search_results['mean_test_AUC'])
accuracies = np.array(grid_search_results['mean_test_Acc'])

# %%
list(aucs)
# Out:
# [0.5, 0.5]

# %%
#parameters
all_params = np.array(grid_search_results['params'])

# %%
#save best models
for i in range(len(aucs)):
    param_grid = all_params[i]
    n_jobs = 1
    solver = param_grid["solver"]
    penalty = param_grid["penalty"]
    current_estimator = LogisticRegression(solver=solver, penalty=penalty, n_jobs=n_jobs)
        
    print(
        ">auroc:" + str(aucs[i]) + 
        " acc:" + (str(accuracies[i]) + 
        " f1:" + (str(f1s[i]) +
        " recall:" + str(recalls[i]) +
        " precision:" + str(precisions[i]) +
        " dataset:" + str(data_set) +
        " model:" + learn_type +  
        " NMFfactors: "+ str(n_factor) + 
        " kmer_size:" + str(kmer_size) + 
        #" no_trees:" + str(trees[i]))) +
        " params:" + str(all_params[i]))))
# Out:
# >auroc:0.5 acc:0.77 f1:0.0021818181818181823 recall:0.005454545454545455 precision:0.0013636363636363637 dataset:['MetaHIT'] model:lassoLR NMFfactors: 5 kmer_size:5 params:{'penalty': 'l1', 'solver': 'saga'}
# >auroc:0.5 acc:0.7727272727272727 f1:0.0 recall:0.0 precision:0.0 dataset:['MetaHIT'] model:lassoLR NMFfactors: 5 kmer_size:5 params:{'penalty': 'l1', 'solver': 'liblinear'}

# %% [markdown]
# # With LassoCV instead

# %%
# just to help run it in jupyter #
learn_type = 'lassoLR'
cv_gridsearch = 10
n_iter_grid = 1
###

param_grid = param_dict[learn_type]

scoring = {
    'Acc': 'accuracy',
    'AUC': 'roc_auc'
}

# %%
kmer_size = 5
n_factor = 25

for data_set in data_sets_to_use:
    data_set = data_set[0]
        
    # Retrieve diseased data and labels
    allowed_labels = ['0', '1']
    kmer_cnts, accessions, labelz, domain_labels = load_kmer_cnts_jf.load_kmers(kmer_size, data_set, allowed_labels)
    print("LOADED DATASET " + str(data_set[0]) + ": " + str(len(kmer_cnts)) + " SAMPLES")
    labelz=np.asarray(labelz).astype(np.int)
# Out:
# MetaHIT
# LOADED DATASET MetaHIT: 110 SAMPLES

# %%
for n in [0, 25]:
    if n == 0:
        data_normalized = normalize(kmer_cnts, axis = 1, norm = 'l1')
        data_normalized, labels = shuffle(data_normalized, labelz, random_state=0) 
        x = data_normalized
        y = labels
                    
    else:
        data_normalized = normalize(kmer_cnts, axis = 1, norm = 'l1')
        data_normalized = stats_utils_AEB.NMF_factor(data_normalized, kmer_size, n_components = int(n), 
                                                     title=(str(data_set) + str(kmer_size) + "mers" 
                                                            + str(n) + "factors"))
        data_normalized, labels = shuffle(data_normalized, labelz, random_state=0)
        x = data_normalized
        y = labels

# %%
param_grid = param_dict[learn_type]

# %%
scoring = {
    'Acc': 'accuracy',
    'AUC': 'roc_auc',
                    }

# %%
k_fold = RepeatedStratifiedKFold(n_splits=cv_gridsearch, n_repeats=n_iter_grid)

# %%
estimator = LogisticRegressionCV(penalty = 'l1', solver = 'saga', cv = k_fold, scoring='roc_auc')

# %%
estimator.fit(x,y)
# Out:
# LogisticRegressionCV(Cs=10, class_weight=None,
#            cv=<sklearn.model_selection._split.RepeatedStratifiedKFold object at 0x7faeb4f57048>,
#            dual=False, fit_intercept=True, intercept_scaling=1.0,
#            max_iter=100, multi_class='warn', n_jobs=None, penalty='l1',
#            random_state=None, refit=True, scoring='roc_auc', solver='saga',
#            tol=0.0001, verbose=0)

# %%
estimator.scores_
# Out:
# {1: array([[0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.59259259, 0.44444444, 0.40740741, 0.44444444],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.62962963, 0.62962963, 0.62962963, 0.62962963],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.51851852, 0.44444444, 0.44444444, 0.40740741],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.81481481, 0.7037037 , 0.77777778, 0.77777778],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.62962963, 0.81481481, 0.81481481, 0.77777778],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.5       , 1.        , 1.        , 1.        ],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.3125    , 0.625     , 0.6875    , 0.6875    ],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.5       , 0.75      , 0.8125    , 0.875     ],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.5625    , 0.625     , 0.625     , 0.625     ],
#         [0.5       , 0.5       , 0.5       , 0.5       , 0.5       ,
#          0.5       , 0.6875    , 0.75      , 0.75      , 0.75      ]])}
